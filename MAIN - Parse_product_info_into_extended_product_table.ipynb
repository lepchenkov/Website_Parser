# %% [markdown]
# <h1>Parse Product Information directly into Postgres Db Table</h1>

# %%
import sys
import os
dir_path = os.getcwd()
sys.path.insert(0,dir_path)
print(sys.path)
# Out:
# ['/home/kiryl/Documents/Projects/Website_Parser', '/home/kiryl/Documents/Environments/scraper/lib/python36.zip', '/home/kiryl/Documents/Environments/scraper/lib/python3.6', '/home/kiryl/Documents/Environments/scraper/lib/python3.6/lib-dynload', '/usr/lib/python3.6', '', '/home/kiryl/Documents/Environments/scraper/lib/python3.6/site-packages', '/home/kiryl/Documents/Environments/scraper/lib/python3.6/site-packages/IPython/extensions', '/home/kiryl/.ipython']

# %%
from parsing_module import *
from sqlalchemy import create_engine, update  
from sqlalchemy import Column, String, Integer, MetaData, Table  
from sqlalchemy.ext.declarative import declarative_base  
from sqlalchemy.orm import sessionmaker
from datetime import datetime

# %% [markdown]
# <h3>Iterate over product links ids and extract product information from each product link, then update database entry</h3>
# <p>Important note! products_all is an extended table that contains columns with product features like name,price etc.</p>

# %%
# %%time
db_string = 'postgresql://postgres:test1234@localhost:5432/oma_catalog_test'
db = create_engine(db_string)
update_set = db.execute("SELECT * FROM products_all WHERE is_parsed IS NULL LIMIT 1000") 
meta = MetaData(db) 
products_all = Table('products_all', \
                               meta, autoload=True, autoload_with=db)

for entry in update_set: 
    response = simple_get(entry.url)
    print(f'entry.id is {entry.id}')
    if response is not None:
        soup = BSoup(response, 'html.parser')
        p_dict = get_product_parameters(soup)
    with db.connect() as conn:
        dt = datetime.now()
        if entry.is_parsed == None:
            update_sttm = products_all.update().where(products_all.c.id==entry.id).values(product_name = p_dict['product_name'], \
                                                                                                   product_price = float(p_dict['product_price']), \
                                                                                                   product_description = p_dict['product_description'], \
                                                                                                   product_characteristics = p_dict['product_characteristics'], \
                                                                                                   similar_products = p_dict['similar_products'], \
                                                                                                   product_image_link = p_dict['product_image_link'], \
                                                                                                   product_is_hit = p_dict['product_is_hit'], \
                                                                                                   is_parsed = dt)                                                                                                    
            conn.execute(update_sttm)
            print('parsed')
        else:
            pass
# Out:
# entry.id is 7785
# parsed
# entry.id is 7786
# parsed
# entry.id is 7787
# parsed
# entry.id is 7788
# parsed
# entry.id is 7789
# parsed
# entry.id is 7790
# parsed
# entry.id is 7791
# parsed
# entry.id is 7792
# parsed
# entry.id is 7793
# parsed
# entry.id is 7794
# parsed
# entry.id is 7795
# parsed
# entry.id is 7796
# parsed
# entry.id is 7797
# parsed
# entry.id is 7798
# parsed
# entry.id is 7799
# parsed
# entry.id is 7800
# parsed
# entry.id is 7801
# parsed
# entry.id is 7802
# parsed
# entry.id is 7803
# parsed
# entry.id is 7804
# parsed
# entry.id is 7805
# parsed
# entry.id is 7806
# parsed
# entry.id is 7807
# parsed
# entry.id is 7808
# parsed
# entry.id is 7809
# parsed
# entry.id is 7810
# parsed
# entry.id is 7811
# parsed
# entry.id is 7812
# parsed
# entry.id is 7813
# parsed
# entry.id is 7814
# parsed
# entry.id is 7815
# parsed
# entry.id is 7816
# parsed
# entry.id is 7817
# parsed
# entry.id is 7818
# parsed
# entry.id is 7819
# parsed
# entry.id is 7820
# ...

# %%
db_string = 'postgresql://postgres:test1234@localhost:5432/oma_catalog_test'
db = create_engine(db_string)
result_set_ = db.execute("SELECT * FROM products_all WHERE id=8779")  
for entry in result_set_:  
    print(f'\n id: {entry.id}')
    print(f'\n url: {entry.url}')
    print(f'\n category: {entry.category}')
    print(f'\n subcategory_lvl1: {entry.subcategory_lvl1}')
    print(f'\n subcategory_lvl2: {entry.subcategory_lvl2}')
    print(f'\n product_name: {entry.product_name}')
    print(f'\n product_price: {entry.product_price}')
    print(f'\n product_description: {entry.product_description}')
    print(f'\n product_charachteristics: {entry.product_characteristics}')
    print(f'\n similar_products: {entry.similar_products}')
    print(f'\n product_image_link: {entry.product_image_link}')
    print(f'\n product_is_hit: {entry.product_is_hit}')
    print(f'\n is_parsed: {entry.is_parsed}')
# Out:
#  id: 8779
#
#  url: https://www.oma.by/ugolok-d-plitki-pvkh-11-12-mm-naruzhnyy-2-5m-belyy-2-260638-p
#
#  category: Отделка
#
#  subcategory_lvl1: Плитка
#
#  subcategory_lvl2: Аксессуары для плитки
#
#  product_name: Уголок д/плитки ПВХ 11-12 мм наружный 2,5м белый, Минск
#
#  product_price: 0.00
#
#  product_description:
#                                     Внутренний угол для керамической плитки. Материал изготовления: ПВХ. Цвет: белый. Станет отличным дополнением к вашим интерьерным решениям.
#
#  product_charachteristics:
#
#  similar_products:
#
#  product_image_link: https://www.oma.by/upload/Sh/imageCache/d37/835/2.260638-medium.jpg
#
#  product_is_hit: False
#
#  is_parsed: 2019-05-14 13:23:59.224818
