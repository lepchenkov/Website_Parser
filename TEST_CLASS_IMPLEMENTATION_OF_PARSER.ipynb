# %% [markdown]
# <h1>Test class implementation of parse.py</h1>

# %%
import sys
import os
dir_path = os.getcwd()
sys.path.insert(0,dir_path)
print(sys.path)
# Out:
# ['/home/kiryl/Documents/Projects/Website_Parser', '/home/kiryl/Documents/Environments/scraper/lib/python36.zip', '/home/kiryl/Documents/Environments/scraper/lib/python3.6', '/home/kiryl/Documents/Environments/scraper/lib/python3.6/lib-dynload', '/usr/lib/python3.6', '', '/home/kiryl/Documents/Environments/scraper/lib/python3.6/site-packages', '/home/kiryl/Documents/Environments/scraper/lib/python3.6/site-packages/IPython/extensions', '/home/kiryl/.ipython']

# %%
from parse import Parser

# %% [markdown]
# <h3>Test parser instance</h3>

# %%
parser = Parser()

i = 0
for name, parent_name  in parser.get_lvl1_subcategories():
    print(i)
    print(name)
    print(parent_name)
    print('\n')
    i += 1
# Out:
# 0
# Анкеры
# Инструменты, крепёж
#
#
# 1
# Бензокосы(травокосилки)/электротриммеры
# Инструменты, крепёж
#
#
# 2
# Болты/ винты/ гайки/ шайбы/шпильки/конфирматы
# Инструменты, крепёж
#
#
# 3
# Газонокосилки
# Инструменты, крепёж
#
#
# 4
# Газосварочное оборудование и материалы
# Инструменты, крепёж
#
#
# 5
# Гвозди
# Инструменты, крепёж
#
#
# 6
# Дрели, шуруповерты, перфораторы, мешалки
# Инструменты, крепёж
#
#
# 7
# Дюбели
# Инструменты, крепёж
#
#
# 8
# Заклепки/ хомуты/ крепеж для сантехники
# Инструменты, крепёж
#
#
# 9
# Замки и дверная фурнитура
# Инструменты, крепёж
#
#
# 10
# Запчасти к электро- пневмоинструменту и станкам
# Инструменты, крепёж
#
#
# 11
# Измельчители/дровоколы/воздуходувки-пылесосы/мотопомпы
# Инструменты, крепёж
#
#
# 12
# Измерительный инструмент
# Инструменты, крепёж
#
#
# 13
# Каркасные системы и крепления
# Инструменты, крепёж
#
#
# 14
# Культиваторы/мотоблоки/электроплуги/минитрактора/райдеры
# Инструменты, крепёж
#
#
# 15
# ...

# %%
for name, parent_name, g_parent_name  in parser.get_lvl2_subcategories():
    print(i)
    print(g_parent_name)
    print(parent_name)
    print(name)
    print('\n')
    i += 1
# Out:
# 189
# Инструменты, крепёж
# Анкеры
# Анкеры рамные
#
#
# 190
# Инструменты, крепёж
# Анкеры
# Анкеры специальные
#
#
# 191
# Инструменты, крепёж
# Анкеры
# Болты анкерные
#
#
# 192
# Инструменты, крепёж
# Бензокосы(травокосилки)/электротриммеры
# Бензокосы (травокосилки) бытовые
#
#
# 193
# Инструменты, крепёж
# Бензокосы(травокосилки)/электротриммеры
# Бензокосы (травокосилки) профессиональные
#
#
# 194
# Инструменты, крепёж
# Бензокосы(травокосилки)/электротриммеры
# Триммеры аккумуляторные
#
#
# 195
# Инструменты, крепёж
# Бензокосы(травокосилки)/электротриммеры
# Триммеры электрические с верхним двигателем
#
#
# 196
# Инструменты, крепёж
# Бензокосы(травокосилки)/электротриммеры
# Триммеры электрические с нижним двигателем
#
#
# 197
# Инструменты, крепёж
# Болты/ винты/ гайки/ шайбы/шпильки/конфирматы
# Болты
#
#
# 198
# Инструменты, крепёж
# Болты/ винты/ гайки/ шайбы/шпильки/конфирматы
# Винты
#
#
# 199
# Инструменты, крепёж
# Болты/ винты/ гайки/ шайбы/шпильки/конфирматы
# ...
