# %% [markdown]
# <h1>Extend product table with new columns</h1>

# %%
import sys
import os
dir_path = os.getcwd()
sys.path.insert(0,dir_path)
print(sys.path)
# Out:
# ['/home/kiryl/Documents/Projects/Website_Parser', '/home/kiryl/Documents/Environments/scraper/lib/python36.zip', '/home/kiryl/Documents/Environments/scraper/lib/python3.6', '/home/kiryl/Documents/Environments/scraper/lib/python3.6/lib-dynload', '/usr/lib/python3.6', '', '/home/kiryl/Documents/Environments/scraper/lib/python3.6/site-packages', '/home/kiryl/Documents/Environments/scraper/lib/python3.6/site-packages/IPython/extensions', '/home/kiryl/.ipython']

# %%
from parsing_module import *
from sqlalchemy import create_engine  
from sqlalchemy import Column, String, Integer  
from sqlalchemy.ext.declarative import declarative_base  
from sqlalchemy.orm import sessionmaker

# %% [markdown]
# <h3>Test iteration over product links to find bugs in features extraction</h3>

# %%
# %%time
db_string = 'postgresql://postgres:test1234@localhost:5432/oma_catalog_test'
db = create_engine(db_string)
result_set = db.execute("SELECT * FROM oma_product_links_copy LIMIT 300")  
for entry in result_set:  
    print(entry.url)
    response = simple_get(entry.url)
    if response is not None:
        soup = BSoup(response, 'html.parser')
        product_dict = get_product_parameters(soup)
        print(product_dict["product_name"])
        print(product_dict["product_price"])
        print(product_dict["product_image_link"])
        print(product_dict["product_is_hit"])
        print("\n")
# Out:
# https://www.oma.by/ankernyy-bolt-s-gaykoy-10kh130-mm-1-211171-p
# Анкерный болт с гайкой 10х130 мм, Минск
#
# 1,10
# https://www.oma.by/upload/Sh/imageCache/46d/cdb/1.211171-medium.jpg
# False
#
#
# https://www.oma.by/ankernyy-bolt-s-gaykoy-8kh85-mm-1-115013-p
# Анкерный болт с гайкой 8х85 мм, Минск
#
# 0,50
# https://www.oma.by/upload/Sh/imageCache/cb7/2b0/1.115013-medium.jpg
# False
#
#
# https://www.oma.by/ankernyy-bolt-s-gaykoy-10-0kh-95-97-mm-10-sht-1-158119-p
# Анкерный болт с гайкой 10,0х 95/97 мм 10 шт, Минск
#
# 9,07
# https://www.oma.by/upload/Sh/imageCache/070/de7/1.158119-medium.jpg
# False
#
#
# https://www.oma.by/ankernyy-bolt-s-kryuchkom-8kh40-mm-1-117543-p
# Анкерный болт с крючком 8х40 мм, Минск
#
# 0,60
# https://www.oma.by/upload/Sh/imageCache/ab3/284/1.117543-medium.jpg
# False
#
#
# https://www.oma.by/ankernyy-bolt-s-gaykoy-12kh150-mm-1-211175-p
# Анкерный болт с гайкой 12х150 мм, Минск
#
# 1,78
# ...

# %%
# %%time
db_string = 'postgresql://postgres:test1234@localhost:5432/oma_catalog_test'
db = create_engine(db_string)
add_col_string = 'ALTER TABLE oma_product_links_copy ADD COLUMN product_price NUMERIC (5, 2) NULL'
db.execute(add_col_string)
# Out:
# CPU times: user 9.79 ms, sys: 0 ns, total: 9.79 ms
# Wall time: 22.5 ms

# %%
# %%time
db_string = 'postgresql://postgres:test1234@localhost:5432/oma_catalog_test'
db = create_engine(db_string)
add_col_string = 'ALTER TABLE oma_product_links_copy ADD COLUMN product_description VARCHAR NULL'
db.execute(add_col_string)
# Out:
# CPU times: user 3.13 ms, sys: 0 ns, total: 3.13 ms
# Wall time: 7.23 ms

# %%
# %%time
db_string = 'postgresql://postgres:test1234@localhost:5432/oma_catalog_test'
db = create_engine(db_string)
add_col_string = 'ALTER TABLE oma_product_links_copy ADD COLUMN product_characteristics VARCHAR NULL'
db.execute(add_col_string)
# Out:
# CPU times: user 3.11 ms, sys: 0 ns, total: 3.11 ms
# Wall time: 7.16 ms

# %%
# %%time
db_string = 'postgresql://postgres:test1234@localhost:5432/oma_catalog_test'
db = create_engine(db_string)
#add_col_string = 'ALTER TABLE oma_product_links_copy ADD COLUMN similar_products VARCHAR NULL'
#db.execute(add_col_string)
# Out:
# CPU times: user 360 µs, sys: 3 µs, total: 363 µs
# Wall time: 367 µs

# %%
# %%time
db_string = 'postgresql://postgres:test1234@localhost:5432/oma_catalog_test'
db = create_engine(db_string)
add_col_string = 'ALTER TABLE oma_product_links_copy ADD COLUMN product_is_hit BOOLEAN NULL'
db.execute(add_col_string)
# Out:
# CPU times: user 0 ns, sys: 3.22 ms, total: 3.22 ms
# Wall time: 7.78 ms

# %%
# %%time
db_string = 'postgresql://postgres:test1234@localhost:5432/oma_catalog_test'
db = create_engine(db_string)
add_col_string = 'ALTER TABLE oma_product_links_copy ADD COLUMN is_parsed TIMESTAMP NULL'
db.execute(add_col_string)
# Out:
# CPU times: user 3.74 ms, sys: 0 ns, total: 3.74 ms
# Wall time: 9.11 ms
