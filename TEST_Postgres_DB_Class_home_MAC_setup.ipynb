# %% [markdown]
# <h1>Test DOWNLOADER </h1>

# %%
import sys
import os
dir_path = os.getcwd()
sys.path.insert(0,dir_path)
print(sys.path)
# Out:
# ['/Users/Lepchenkov/Desktop/Python/Website_Parser', '/Library/Frameworks/Python.framework/Versions/3.6/lib/python36.zip', '/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6', '/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/lib-dynload', '', '/Users/Lepchenkov/Library/Python/3.6/lib/python/site-packages', '/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages', '/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/Django-2.2.dev20180903084355-py3.6.egg', '/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/extensions', '/Users/Lepchenkov/.ipython']

# %%
from db_connect import Postgres_db
from parse import Parser
from downloader import Downloader

# %% [markdown]
# <h3>List all tables</h3>

# %%
# db_config = 'postgresql://postgres:test1234@localhost:5432/oma_catalog_test'
db_config = 'postgresql://postgres:mypassword@localhost:5432/oma_catalog_test'
db = Postgres_db(db_config)

select_all_tables = "SELECT table_name FROM information_schema.tables WHERE table_schema='public'"
result_set = db._query(select_all_tables)
print('Complete list of tables present in the database:')
for result in result_set:
    print(result)
# Out:
# Complete list of tables present in the database:
# ('categories',)
# ('subcategories_lvl1',)
# ('subcategories_lvl2',)
# ('products',)
# ('product_properties',)

# %% [markdown]
# <h3>Drop all tables</h3>

# %%
db_config = 'postgresql://postgres:test1234@localhost:5432/oma_catalog_test'

# db._query("DROP TABLE categories, subcategories_lvl1;")
db.drop_existing_tables_from_db()
select_all_tables = "SELECT table_name FROM information_schema.tables WHERE table_schema='public'"
result_set = db._query(select_all_tables)
print('Complete list of tables present in the database:')
for result in result_set:
    print(result)
# Out:
# Complete list of tables present in the database:

# %% [markdown]
# <h3>Instantiate downloader</h3>

# %%
dwnld = Downloader(db_config, create_new_tables=True)

# %% [markdown]
# <h3>Parse categories</h3>

# %%
dwnld.parse_categories()
result_set = db._query("SELECT * FROM categories")
for result in result_set:
    print(result)
# Out:
# (1, 'Инструменты, крепёж')
# (2, 'Отделка')
# (3, 'Садовый центр / отдых')
# (4, 'Сантехника')
# (5, 'Строительство')
# (6, 'Товары для дома')
# (7, 'Электротехника')

# %% [markdown]
# <h3>Parse subcategories</h3>

# %%
dwnld.parse_lvl1_subcategories()
result_set = db._query("SELECT * FROM subcategories_lvl1")
for result in result_set:
    print(result)
# Out:
# (1, 'Анкеры', 1)
# (2, 'Бензокосы(травокосилки)/электротриммеры', 1)
# (3, 'Болты/ винты/ гайки/ шайбы/шпильки/конфирматы', 1)
# (4, 'Газонокосилки', 1)
# (5, 'Газосварочное оборудование и материалы', 1)
# (6, 'Гвозди', 1)
# (7, 'Дрели, шуруповерты, перфораторы, мешалки', 1)
# (8, 'Дюбели', 1)
# (9, 'Заклепки/ хомуты/ крепеж для сантехники', 1)
# (10, 'Замки и дверная фурнитура', 1)
# (11, 'Запчасти к электро- пневмоинструменту и станкам', 1)
# (12, 'Измельчители/дровоколы/воздуходувки-пылесосы/мотопомпы', 1)
# (13, 'Измерительный инструмент', 1)
# (14, 'Каркасные системы и крепления', 1)
# (15, 'Культиваторы/мотоблоки/электроплуги/минитрактора/райдеры', 1)
# (16, 'Кусторезы/секаторы/скарификаторы/аэраторы', 1)
# (17, 'Мебельная фурнитура', 1)
# (18, 'Оснастка для зачистки, шлифовки и полировки', 1)
# (19, 'Оснастка для пиления, строгания, фрезерования', 1)
# (20, 'Оснастка для сверления и завинчивания', 1)
# (21, 'Оснастка к садовой технике', 1)
# (22, 'Паяльники, припои, флюсы', 1)
# (23, 'Пилы цепные', 1)
# (24, 'Пилы, лобзики, рубанки, фрезеры', 1)
# (25, 'Пневмоинструмент', 1)
# (26, 'Портативные горелки, баллоны с газом, лампы паяльные', 1)
# (27, 'Пылесосы, моечные аппараты и оснастка к ним', 1)
# (28, 'Резьбонарезные инструменты и сопутствующие', 1)
# (29, 'Слесарный инструмент', 1)
# (30, 'Снегоуборщики', 1)
# (31, 'Специальные электроинструменты', 1)
# (32, 'Станки и оборудование', 1)
# (33, 'Столярный инструмент', 1)
# (34, 'Строительный инструмент', 1)
# (35, 'Цепи/ тросы/ аксессуары к ним', 1)
# (36, 'Части для электроинструментов и спецоснастка', 1)
# (37, 'Шлифмашины, полирователи, бороздоделы', 1)
# (38, 'Шурупы/ заглушки', 1)
# (39, 'Электросварочное оборудование и материалы', 1)
# (40, 'Ящики для инструмента , органайзеры', 1)
# (41, 'Герметизирующие материалы', 2)
# (42, 'Грунты', 2)
# (43, 'Декоративные элементы', 2)
# (44, 'Деревозащитные средства', 2)
# (45, 'Добавки к лкм', 2)
# (46, 'Клеи специализированные', 2)
# (47, 'Клей для обоев', 2)
# (48, 'Ковры и ковровое покрытие', 2)
# (49, 'Краски для внутренних работ', 2)
# (50, 'Краски для наружных работ', 2)
# (51, 'Лаки', 2)
# (52, 'Ламинированный пол', 2)
# (53, 'Линолеум', 2)
# (54, 'Лкм аэрозольные', 2)
# (55, 'Малярный инструмент', 2)
# (56, 'Обои', 2)
# (57, 'Панели', 2)
# (58, 'Паркет', 2)
# (59, 'Пленка декоративная', 2)
# (60, 'Плинтуса / порожки', 2)
# (61, 'Плитка', 2)
# (62, 'Потолок из пенополистирола', 2)
# (63, 'Пробковое покрытие', 2)
# (64, 'Растворители', 2)
# (65, 'Специализированные покрытия', 2)
# (66, 'Стеклообои', 2)
# (67, 'Фотообои и наклейки', 2)
# (68, 'Эмали', 2)
# (69, 'Автокосметика', 3)
# (70, 'Автохимия', 3)
# (71, 'Банные принадлежности', 3)
# (72, 'Мебель для сада и парка', 3)
# (73, 'Оснащение авто', 3)
# (74, 'Печи, камины и комплектующие', 3)
# (75, 'Покраска авто', 3)
# (76, 'Поливочный инвентарь', 3)
# (77, 'Посадочно-уборочный инвентарь', 3)
# (78, 'Садовая химия', 3)
# (79, 'Садовый декор', 3)
# (80, 'Семена, цветы, саженцы', 3)
# (81, 'Товары для отдыха', 3)
# (82, 'Товары для спорта', 3)
# (83, 'Уход за растениями', 3)
# (84, 'Аксессуары для ванных комнат', 4)
# (85, 'Ванны', 4)
# (86, 'Внутренняя канализация', 4)
# (87, 'Водонагреватели ', 4)
# (88, 'Домашняя вентиляция', 4)
# (89, 'Душевое оборудование', 4)
# (90, 'Душевые кабины', 4)
# (91, 'Лючки и дверки ревизионные', 4)
# (92, 'Мебель  для ванных комнат', 4)
# (93, 'Мойки кухонные', 4)
# (94, 'Насосы', 4)
# (95, 'Подводка воды', 4)
# (96, 'Полотенцесушители', 4)
# (97, 'Радиаторы и отопление', 4)
# (98, 'Система наружной канализации', 4)
# (99, 'Системы очистки воды', 4)
# (100, 'Сифоны', 4)
# (101, 'Смесители', 4)
# (102, 'Умывальники, пьедесталы', 4)
# (103, 'Унитазы, писсуары, биде', 4)
# (104, 'Блоки', 5)
# (105, 'Гипсокартон', 5)
# (106, 'Двери межкомнатные', 5)
# (107, 'Двери металлические', 5)
# (108, 'Двери специальные', 5)
# (109, 'Декоративный камень', 5)
# (110, 'Доборные элементы', 5)
# (111, 'Другие изоляционные материалы, аксессуары', 5)
# (112, 'Изделия из металла', 5)
# (113, 'Каменная вата', 5)
# (114, 'Кирпич', 5)
# (115, 'Клеи строительные', 5)
# (116, 'Комплектующие для гипсокартонных систем', 5)
# (117, 'Кровельные материалы', 5)
# (118, 'Лестницы', 5)
# (119, 'Ливневые системы', 5)
# (120, 'Листовые материалы', 5)
# (121, 'Материалы для подготовки поверхности', 5)
# (122, 'Металлопрокат', 5)
# (123, 'Окна', 5)
# (124, 'Оконные доборные элементы', 5)
# (125, 'Пенополистирол, экструдированный пенополистирол', 5)
# (126, 'Пенополиэтилен', 5)
# (127, 'Пиломатериалы', 5)
# (128, 'Пленки строительные', 5)
# (129, 'Подвесной потолок', 5)
# (130, 'Полимерные и композитные материалы', 5)
# (131, 'Рукавицы, перчатки', 5)
# (132, 'Сайдинг', 5)
# (133, 'Сезонная одежда и обувь', 5)
# (134, 'Спецобувь', 5)
# (135, 'Спецодежда', 5)
# (136, 'Средства защиты', 5)
# (137, 'Стеклянная вата', 5)
# (138, 'Строительные и кладочные смеси', 5)
# (139, 'Строительные машины', 5)
# (140, 'Строительный инвентарь', 5)
# (141, 'Тротуарная плитка', 5)
# (142, 'Фуга', 5)
# (143, 'Бытовая химия', 6)
# (144, 'Емкости для кухни', 6)
# (145, 'Жалюзи', 6)
# (146, 'Карнизы ', 6)
# (147, 'Климатическая бытовая техника', 6)
# (148, 'Крупная бытовая техника', 6)
# (149, 'Кухни', 6)
# (150, 'Кухонная бытовая техника', 6)
# (151, 'Мебель  для ванных комнат', 6)
# (152, 'Мебель для прихожих', 6)
# (153, 'Мебель и товары для хранения', 6)
# (154, 'Мебель офисная', 6)
# (155, 'Мебель столовая', 6)
# (156, 'Мелкая бытовая техника', 6)
# (157, 'Новый год', 6)
# (158, 'Офисные товары', 6)
# (159, 'Парфюмерно-косметические товары', 6)
# (160, 'Посуда', 6)
# (161, 'Предметы декора и сувениры', 6)
# (162, 'Роллеты', 6)
# (163, 'Средства личной гигиены', 6)
# (164, 'Стиральные моющие средства', 6)
# (165, 'Текстиль', 6)
# (166, 'Товары бытового назначения', 6)
# (167, 'Товары для детей', 6)
# (168, 'Товары для уборки', 6)
# (169, 'Товары для ухода за одеждой, обувью', 6)
# (170, 'Товары для хобби', 6)
# (171, 'Упаковка', 6)
# (172, 'Шторы', 6)
# (173, 'Домашняя безопасность', 7)
# (174, 'Кабеленесущие системы', 7)
# (175, 'Кабельно- проводниковая продукция', 7)
# (176, 'Лампы бытовые', 7)
# (177, 'Лампы промышленные', 7)
# (178, 'Материалы для монтажа телефонной, телевизионной связи', 7)
# (179, 'Приборы учета, контроля, преобразования', 7)
# (180, 'Розетки и выключатели', 7)
# (181, 'Садовые светильники', 7)
# (182, 'Светильники декоративные (для дома)', 7)
# (183, 'Светильники хозяйственных и общественных помещений', 7)
# (184, 'Светодиодное оборудование', 7)
# (185, 'Удлинители', 7)
# (186, 'Фонари, батарейки, аккумуляторы для них', 7)
# (187, 'Электрические теплые полы', 7)
# (188, 'Электромонтажные материалы', 7)
# (189, 'Электрощитовое оборудование', 7)
